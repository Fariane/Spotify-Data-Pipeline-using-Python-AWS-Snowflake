# %%
#Installing spotipy package
# !pip install spotipy

# %%
#Importing necessary libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id = "" , client_secret="")

# %%
#Initializes a Spotify client using Spotipy with a client credentials manager for API authentication
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
#extracting only playlist uri
playlist_URI = playlist_link.split("/")[-1]

# %%
playlist_URI
# Out:
# '5ABHKGoOzxkaa28ttQV9sE'

# %%
#retrives data from uri and stores in data
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5ABHKGoOzxkaa28ttQV9sE/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-02-15T21:57:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#     'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#     'id': 'jonathan.holgersson',
#     'type': 'user',
#     'uri': 'spotify:user:jonathan.holgersson'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2024-02-15T21:57:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#    'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#    'id': 'jonathan.holgersson',
#    'type': 'user',
#    'uri': 'spotify:user:jonathan.holgersson'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
# ...

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 14

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_name)
# Out:
# After Hours
# ÷ (Deluxe)
# Divinely Uninspired To A Hellish Extent
# Harry's House
# Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)
# Starboy
# Views
# F*CK LOVE 3: OVER YOU
# I Love You.
# Evolve
# Heat Waves
# Dance Monkey (Stripped Back) / Dance Monkey
# ÷ (Deluxe)
# rockstar
# Tunnel Of Love
# lovely (with Khalid)
# Back from the Edge
# Sunlight
# Closer
# Fine Line
# Señorita
# Memories...Do Not Open
# where do i go?
# Dream Your Life Away
# Future Nostalgia
# Hozier (Special Edition)
# Long Way Down (Deluxe)
# Native
# Rewrite
# x (Deluxe Edition)
# Like Em Country
# Goodbye & Good Riddance
# Hollywood's Bleeding
# Cool Girls Party
# Scary Hours
# A Night At The Opera (2011 Remaster)
# WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# x (Deluxe Edition)
# The Heist
# Glow
# Parachutes
# Birds In The Trap Sing McKnight
# A Star Is Born Soundtrack
# Because I'm Blonde
# Lover
# Purpose (Deluxe)
# AM
# Evolve
# Love In The Future (Expanded Edition)
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_name, 'name':album_name, 'release_date':album_release_date, 'total_tracks' : album_total_tracks, 'url': album_url}
    print(album_element)
# Out:
# {'album_id': 'After Hours', 'name': 'After Hours', 'release_date': '2020-03-20', 'total_tracks': 14, 'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'}
# {'album_id': '÷ (Deluxe)', 'name': '÷ (Deluxe)', 'release_date': '2017-03-03', 'total_tracks': 16, 'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'}
# {'album_id': 'Divinely Uninspired To A Hellish Extent', 'name': 'Divinely Uninspired To A Hellish Extent', 'release_date': '2019-05-17', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'}
# {'album_id': "Harry's House", 'name': "Harry's House", 'release_date': '2022-05-20', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'}
# ...

# %%
#creating a albumlist with the relevant columns
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_name, 'name':album_name, 'release_date':album_release_date, 'total_tracks' : album_total_tracks, 'url': album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': 'After Hours',
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '÷ (Deluxe)',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': 'Divinely Uninspired To A Hellish Extent',
#   'name': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': "Harry's House",
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %%
#creating a artistlist with the relevant columns
artist_list = []

for row in data['items']:
    for key, value in row.items():
        if key == "track" :
            for artist in value['artists']:
                artist_dict = {'artist_id' : artist['id'], 'artist_name' : artist['name'], 'artist_name' : artist['name'], 'external_url' : artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'artist_name': 'Lewis Capaldi',
#   'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '1zNqQNIdeOUZHb8zbZRFMX',
#   'artist_name': 'Swae Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
# ...

# %%
#creating a songlist with the relevant columns
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'duration_ms': 200040,
#   'url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'popularity': 87,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'duration_ms': 233712,
#   'url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'popularity': 86,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
#   'song_name': 'Someone You Loved',
#   'duration_ms': 182160,
#   'url': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf',
#   'popularity': 86,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '5658aM19fA3JVwTK6eQX70',
#   'artist_id': '4GNC7GD6oZMSxPGyXy4MNB'},
# ...

# %%
#converting into df
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                                              album_id  \
# 0                                         After Hours
# 1                                          ÷ (Deluxe)
# 2             Divinely Uninspired To A Hellish Extent
# 3                                       Harry's House
# 4   Spider-Man: Into the Spider-Verse (Soundtrack ...
# ..                                                ...
# 95             The Thrill Of It All (Special Edition)
# 96                                 In The Lonely Hour
# 97                                        Daydreaming
# 98                                                SOS
# 99                                             Camila
#
#                                                  name release_date  \
# 0                                         After Hours   2020-03-20
# 1                                          ÷ (Deluxe)   2017-03-03
# 2             Divinely Uninspired To A Hellish Extent   2019-05-17
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df.head()
# Out:
#                                             album_id  \
# 0                                        After Hours
# 1                                         ÷ (Deluxe)
# 2            Divinely Uninspired To A Hellish Extent
# 3                                      Harry's House
# 4  Spider-Man: Into the Spider-Verse (Soundtrack ...
#
#                                                 name release_date  \
# 0                                        After Hours   2020-03-20
# 1                                         ÷ (Deluxe)   2017-03-03
# 2            Divinely Uninspired To A Hellish Extent   2019-05-17
# 3                                      Harry's House   2022-05-20
# 4  Spider-Man: Into the Spider-Verse (Soundtrack ...   2018-12-14
#
#    total_tracks                                                url
# 0            14  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1            16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# ...

# %%
#dropping duplicates
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                                              album_id  \
# 0                                         After Hours
# 1                                          ÷ (Deluxe)
# 2             Divinely Uninspired To A Hellish Extent
# 3                                       Harry's House
# 4   Spider-Man: Into the Spider-Verse (Soundtrack ...
# ..                                                ...
# 95             The Thrill Of It All (Special Edition)
# 96                                 In The Lonely Hour
# 97                                        Daydreaming
# 98                                                SOS
# 99                                             Camila
#
#                                                  name release_date  \
# 0                                         After Hours   2020-03-20
# 1                                          ÷ (Deluxe)   2017-03-03
# 2             Divinely Uninspired To A Hellish Extent   2019-05-17
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      91 non-null     object
#  1   name          91 non-null     object
#  2   release_date  91 non-null     object
#  3   total_tracks  91 non-null     int64
#  4   url           91 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.3+ KB

# %%
#converting artistlist to df
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id     artist_name  \
# 0    1Xyo4u8uXC1ZmMpatF05PJ      The Weeknd
# 1    6eUKZXaKkcviH0Ku9w2n3V      Ed Sheeran
# 2    4GNC7GD6oZMSxPGyXy4MNB   Lewis Capaldi
# 3    6KImCVD70vtIoJWnq6nGn3    Harry Styles
# 4    246dkjvS1zLTtiykXe5h60     Post Malone
# ..                      ...             ...
# 122  2wY79sveU1sp5g7SokKOiI       Sam Smith
# 123  4fjAtF6VmMxQHxKI5C3HPO         Bruklin
# 124  7tYKF4w9nC0nq9CsPZTHyP             SZA
# 125  4nDoRrQiYLoBzwC5BhVJzF  Camila Cabello
# 126  50co4Is1HCEo8bhOyUWKpn      Young Thug
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1    https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2    https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 3    https://api.spotify.com/v1/artists/6KImCVD70vt...
# 4    https://api.spotify.com/v1/artists/246dkjvS1zL...
# ..                                                 ...
# ...

# %%
#dropping duplicates
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                      song_name  \
# 0   0VjIjW4GlUZAMYd2vXMi3b                                Blinding Lights
# 1   7qiZfU4dY1lWllzX7mPBI3                                   Shape of You
# 2   7qEHsqek33rTcFNT9PFqLf                              Someone You Loved
# 3   4Dvkj6JhhA12EX05fT7y2e                                      As It Was
# 4   3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# ..                     ...                                            ...
# 95  1mXVgsBdtIVeCLJnSnmtdV                           Too Good At Goodbyes
# 96  2whoe0pPKh4JRn6eWSIqTV                                   Stay With Me
# 97  6QkEV7Krf7WV2UdILlgN4Z                                    Daydreaming
# 98  3OHfY25tqY28d16oZczHc8                                      Kill Bill
# 99  1rfofaqEpACxVEHIZBJe6W                      Havana (feat. Young Thug)
#
#     duration_ms                                                url  \
# ...

# %%
#transforming release_date to datetime datatype
album_df['release_date'] = pd.to_datetime(album_df['release_date'], format='mixed', errors='coerce')
# Out:
# C:\Users\Fariane\AppData\Local\Temp\ipykernel_16008\460558561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'], format='mixed', errors='coerce')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      91 non-null     object
#  1   name          91 non-null     object
#  2   release_date  91 non-null     datetime64[ns]
#  3   total_tracks  91 non-null     int64
#  4   url           91 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
#transforming song_added to datetime datatype
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
